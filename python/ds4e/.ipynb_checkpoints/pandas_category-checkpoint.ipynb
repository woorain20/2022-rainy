# %% [markdown]
# # 범주형 변수_탐색적 분석

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# 기술 데이터 값
df.describe(include="object")
# Out:
#        origin        name
# count     398         398
# unique      3         305
# top       usa  ford pinto
# freq      249           6

# %%
sns.countplot(data=df, x="origin")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
sns.countplot(data=df, y="origin")
# Out:
# <AxesSubplot:xlabel='count', ylabel='origin'>

# %%
df["origin"].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
sns.countplot(data=df, x="cylinders")
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
df["cylinders"].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sns.countplot(data=df, x="model_year")
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='count'>

# %%
df["model_year"].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: model_year, dtype: int64

# %%
sns.countplot(data=df, x="origin", hue="cylinders")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
sns.countplot(data=df, x="cylinders", hue="origin")
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
pd.crosstab(df["origin"], df['cylinders'])
# Out:
# cylinders  3   4  5   6    8
# origin
# europe     0  63  3   4    0
# japan      4  69  0   6    0
# usa        0  72  0  74  103

# %%
sns.barplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
# barplot - 막대그래프를 그려주며, 범주형 데이터와 잘 쓰임
# 검은색 막대는 신뢰구간을 표시

# %%
sns.barplot(data=df, x="origin", y="mpg", ci=None)
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_3032\994581456.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="origin", y="mpg", ci=None)
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.barplot(data=df, x="origin", y="mpg", errorbar=None)
# ci를 errorbar로 하면 에러 안 뜸
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.barplot(data=df, x="origin", y="mpg", estimator="sum")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
df.groupby("origin").mean()
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# japan   30.450633   4.101266    102.708861   79.835443  2221.227848
# usa     20.083534   6.248996    245.901606  119.048980  3361.931727
#
#         acceleration  model_year
# origin
# europe     16.787143   75.814286
# japan      16.172152   77.443038
# usa        15.033735   75.610442

# %%
df.groupby("origin")["mpg"].mean()
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
pd.pivot_table(data=df, index="origin", values="mpg")
# Out:
#               mpg
# origin
# europe  27.891429
# japan   30.450633
# usa     20.083534

# %%
pd.pivot_table(data=df, index="cylinders", values="mpg")
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
sns.barplot(data=df, x="origin", y="mpg", hue="cylinders")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
pd.pivot_table(data=df, index="cylinders", columns="origin", values='mpg')
# Out:
# origin        europe      japan        usa
# cylinders
# 3                NaN  20.550000        NaN
# 4          28.411111  31.595652  27.840278
# 5          27.366667        NaN        NaN
# 6          20.100000  23.883333  19.663514
# 8                NaN        NaN  14.963107

# %%
sns.boxplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
df.groupby("origin").describe()
# Out:
#           mpg                                                     cylinders  \
#         count       mean       std   min   25%   50%    75%   max     count
# origin
# europe   70.0  27.891429  6.723930  16.2  24.0  26.5  30.65  44.3      70.0
# japan    79.0  30.450633  6.090048  18.0  25.7  31.6  34.05  46.6      79.0
# usa     249.0  20.083534  6.402892   9.0  15.0  18.5  24.00  39.0     249.0
#
#                   ... acceleration       model_year                       \
#             mean  ...          75%   max      count       mean       std
# origin            ...
# europe  4.157143  ...        18.90  24.8       70.0  75.814286  3.469506
# japan   4.101266  ...        17.55  21.0       79.0  77.443038  3.650595
# usa     6.248996  ...        16.90  22.2      249.0  75.610442  3.677094
#
#
#          min   25%   50%   75%   max
# origin
# europe  70.0  73.0  76.0  79.0  82.0
# japan   70.0  74.0  78.0  81.0  82.0
# usa     70.0  73.0  76.0  79.0  82.0
#
# [3 rows x 56 columns]

# %%
origin_desc=df.groupby("origin")["mpg"].describe()
origin_desc
# Out:
#         count       mean       std   min   25%   50%    75%   max
# origin
# europe   70.0  27.891429  6.723930  16.2  24.0  26.5  30.65  44.3
# japan    79.0  30.450633  6.090048  18.0  25.7  31.6  34.05  46.6
# usa     249.0  20.083534  6.402892   9.0  15.0  18.5  24.00  39.0

# %%
df.groupby("model_year").describe()
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# 81          29.0  30.334483  5.591465  17.6  26.600  31.60  34.400  39.1
# 82          31.0  31.709677  5.392548  22.0  27.000  32.00  36.000  44.0
#
#            cylinders            ...   weight         acceleration             \
#                count      mean  ...      75%     max        count       mean
# model_year                      ...
# 70              29.0  6.758621  ...  4312.00  4732.0         29.0  12.948276
# 71              28.0  5.571429  ...  3603.25  5140.0         28.0  15.142857
# 72              28.0  5.821429  ...  4169.75  4633.0         28.0  15.125000
# 73              40.0  6.375000  ...  4247.25  4997.0         40.0  14.312500
# 74              27.0  5.259259  ...  3622.50  4699.0         27.0  16.203704
# 75              30.0  5.600000  ...  3662.25  4668.0         30.0  16.050000
# 76              34.0  5.647059  ...  3803.75  4380.0         34.0  15.941176
# 77              28.0  5.464286  ...  3925.00  4335.0         28.0  15.435714
# 78              36.0  5.361111  ...  3410.00  4080.0         36.0  15.805556
# 79              29.0  5.827586  ...  3725.00  4360.0         29.0  15.813793
# 80              29.0  4.137931  ...  2800.00  3381.0         29.0  16.934483
# 81              29.0  4.620690  ...  2900.00  3725.0         29.0  16.306897
# 82              31.0  4.193548  ...  2727.50  3035.0         31.0  16.638710
#
#
#                  std   min     25%    50%     75%   max
# model_year
# 70          3.330982   8.0  10.000  12.50  15.000  20.5
# 71          2.666171  11.5  13.375  14.50  16.125  20.5
# 72          2.850032  11.0  13.375  14.50  16.625  23.5
# 73          2.754222   9.5  12.500  14.00  16.000  21.0
# 74          1.688532  13.5  15.250  16.00  17.000  21.0
# 75          2.471737  11.5  14.125  16.00  17.375  21.0
# 76          2.801419  12.0  13.925  15.50  17.550  22.2
# 77          2.273391  11.1  14.000  15.65  16.925  19.0
# 78          2.129915  11.2  14.475  15.75  16.825  21.5
# 79          2.952931  11.3  14.000  15.00  17.300  24.8
# 80          2.826694  11.4  15.100  16.50  18.700  23.7
# 81          2.192509  12.6  14.800  16.20  17.300  20.7
# 82          2.484844  11.6  14.850  16.40  18.000  24.6
#
# [13 rows x 48 columns]

# %%
df.groupby("model_year")["horsepower"].describe()
# Out:
#             count        mean        std   min    25%    50%     75%    max
# model_year
# 70           29.0  147.827586  53.734844  46.0  95.00  150.0  198.00  225.0
# 71           27.0  107.037037  38.566109  60.0  81.00   95.0  130.00  180.0
# 72           28.0  120.178571  41.121368  54.0  86.75  104.5  150.75  208.0
# 73           40.0  130.475000  46.412304  46.0  93.25  129.5  160.25  230.0
# 74           26.0   94.230769  29.686775  52.0  75.00   88.0  103.75  150.0
# 75           30.0  101.066667  26.577062  53.0  84.25   97.0  110.00  170.0
# 76           34.0  101.117647  32.430592  52.0  78.25   93.5  120.00  180.0
# 77           28.0  105.071429  36.095479  58.0  78.00   97.5  115.00  190.0
# 78           36.0   99.694444  28.436214  48.0  82.50   97.0  116.25  165.0
# 79           29.0  101.206897  28.455955  65.0  77.00   90.0  125.00  155.0
# 80           27.0   77.481481  18.173037  48.0  66.00   75.0   90.00  132.0
# 81           28.0   81.035714  18.105620  58.0  65.00   75.5   89.00  120.0
# 82           30.0   81.466667  13.296962  52.0  70.00   84.0   88.00  112.0

# %%
# 행만 가져 올 때 loc
df.loc[1]
# Out:
# mpg                          15.0
# cylinders                       8
# displacement                350.0
# horsepower                  165.0
# weight                       3693
# acceleration                 11.5
# model_year                     70
# origin                        usa
# name            buick skylark 320
# Name: 1, dtype: object

# %%
origin_desc.loc["europe"]
# Out:
# count    70.000000
# mean     27.891429
# std       6.723930
# min      16.200000
# 25%      24.000000
# 50%      26.500000
# 75%      30.650000
# max      44.300000
# Name: europe, dtype: float64

# %%
sns.boxenplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.scatterplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.stripplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.swarmplot(data=df, x="origin", y="mpg")
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.swarmplot(data=df, x="origin", y="mpg", size=3)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(10,4))
sns.swarmplot(data=df, x="origin", y="mpg", size= 3)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
# plt 임포트 필요

# %%
# 기본형
sns.catplot(data=df, x="origin", y="mpg")

# %%
sns.catplot(data=df, x="origin", y="mpg", kind="box")

# %%
sns.catplot(data=df, x="origin", y="mpg", kind="bar")

# %%
sns.catplot(data=df, x="origin", y="mpg", kind="point")

# %%
# catplot 하나로 kind만 바꿔주면 다양한 형태의 그래프로 변환가능
# strip, swarm, bar, box, violin, point

# %%
sns.catplot(data=df, x="origin", y="mpg", col="cylinders")

# %%
sns.catplot(data=df, x="origin", y="mpg", col="cylinders", col_wrap=3)
# col_wrap - 한 줄에 넣을 그래프 수

# %%
sns.catplot(data=df, x="origin", y="weight", col="cylinders")
