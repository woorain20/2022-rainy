# %% [markdown]
# # 수치형 변수

# %%
import pandas as pd
import seaborn as sns
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.4.4
# 0.12.0

# %%
# df -> pandas -> data frame
df=sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# 히스토그램 - 표로 되어 있는 도수 분포
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model_year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# 글자가 잘 안 보여서 크기 조정
df.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model_year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# bins 조정하면 데이터 범위가 달라져서 세부범위 확인 가능(bins 숫자 클수록 세세한 범위 확인 가능)
df.hist(figsize=(10,8), bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model_year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# 비대칭도(왜도)
# 왜도가 음수일 경우에는 오른쪽으로 기운다
# 왜도가 양수일 경우에는 왼쪽으로 기운다
# 평균과 중앙값이 같으면 0
# skew - 왜도 구하기
df.skew()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_11656\2261509808.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# mpg             0.457066
# cylinders       0.526922
# displacement    0.719645
# horsepower      1.087326
# weight          0.531063
# acceleration    0.278777
# model_year      0.011535
# dtype: float64

# %%
# 첨도
# 확률 분포의 뾰족한 정도를 나타내는 척도
# 데이터가 어느 곳에 집중적으로 몰려 있는가를 측정할 때 사용
# 첨도값이 3에 가까울수록 정규분포에 가깝다
# 첨도 < 3 더 뾰족한 분포(꼬리가 얇다) 
# 첨도 > 3 더 완만하고 납작한 분포(꼬리가 두꺼운 분포)
# kurt() - 첨도 구하기
df.kurt()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_11656\1175189072.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.kurt()
# mpg            -0.510781
# cylinders      -1.376662
# displacement   -0.746597
# horsepower      0.696947
# weight         -0.785529
# acceleration    0.419497
# model_year     -1.181232
# dtype: float64

# %%
# seaborn -> 히스토그램 -> displot()
sns.displot(data=df, x="mpg")

# %%
sns.displot(data=df, x="mpg", kde=True)
# kde - 선을 그려줌

# %%
# kdeplot() - 선으로 밀도 함수 표현
sns.kdeplot(data=df, x="mpg")
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="mpg", shade=True)
# shade - 색 표시
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_11656\3919317648.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x="mpg", shade=True)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
# mpg 값에 대해 skew, kurt 값 구하기
# 하나의 칼럼 객체 -> 시리즈(Serise)
df["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df["mpg"].agg(["skew", "kurt"])
# Out:
# skew    0.457066
# kurt   -0.510781
# Name: mpg, dtype: float64

# %%
# boxplot으로 mpg의 사분위 수 시각화
sns.boxplot(data=df, x="mpg")
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.boxplot(data=df, x="weight")
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
# 가장 왼쪽 선은 최솟값, 가장 오른쪽 선은 최댓값, 두번째 왼쪽 값은 25%, 두번째 오른쪽 값은 50%, 다이아몬드가 있으면 100% or 0% 밖의 값이 존재한다

# %%
# mpg 기술통계 값 구하기
df["mpg"].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
# violinplot - 그리기
sns.violinplot(data=df, x="mpg")
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
# 흰 점이 평균, 검은색 박스가 25%값 75%값

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.head(1)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu

# %%
sns.violinplot(data=df, x="weight")
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
# scatterplot - 2개의 데이터 수치 비교하기
sns.scatterplot(data=df, x="weight", y="mpg")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.scatterplot(data=df, x="weight", y="horsepower")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='horsepower'>

# %%
# hue = 색 구분
sns.scatterplot(data=df, x="weight", y="mpg", hue="origin")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.scatterplot(data=df, x="weight", y="horsepower", hue="origin")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='horsepower'>

# %%
# regplot - 회귀선 그리기
sns.regplot(data=df, x="weight", y="mpg")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
# 회귀선의 잔차를 시각화 사기
sns.residplot(data=df, x="weight", y="mpg")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.lmplot(data=df, x="weight", y="mpg", hue="origin")

# %%
sns.lmplot(data=df, x="weight", y="mpg", hue="origin", col="origin")

# %%
sns.jointplot(data=df, x="weight", y="mpg")

# %%
sns.jointplot(data=df, x="weight", y="mpg", kind="hex")

# %%
import pandas as pd
import seaborn as sns
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.4.4
# 0.12.0

# %%
df=sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# 다시 켰을 때는 import 필요함

# %%
sns.pairplot(data=df)

# %%
df_sample=df.sample(100, random_state=42)
sns.pairplot(data=df_sample, hue="origin")

# %%
sns.pairplot(df, y_vars=["mpg"])

# %%
sns.scatterplot(data=df, x="model_year", y="mpg")
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
# 평균을 나타냄
sns.lineplot(data=df, x="model_year", y="mpg")
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
sns.lineplot(data=df, x="model_year", y="mpg", ci=None)
# ci=None - 신뢰구간 없애기
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_10564\3599197761.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="model_year", y="mpg", ci=None)
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
sns.lineplot(data=df, x="cylinders", y="mpg", ci=95)
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_10564\3049752065.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(data=df, x="cylinders", y="mpg", ci=95)
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
sns.relplot(data=df, x="model_year", y="mpg", hue="origin", col="origin")

# %%
sns.relplot(data=df)

# %%
sns.relplot(data=df, x="model_year", y="mpg", hue="origin", col="origin", kind="line")

# %%
sns.relplot(data=df, x="weight", y="mpg", hue="origin", col="origin", kind="line")

# %%
sns.relplot(data=df, x="horsepower", y="mpg", hue="origin", col="origin", kind="line")

# %%
# 상관관계 찾기
corr=df.corr()
corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
# 상관관계를 시각화
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# plt colormap 참고
# cmap - 활용하면 색 변화 가능

# %%
sns.heatmap(corr, cmap="autumn")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr, cmap="autumn", annot=True)
# annot - True 일 경우 숫자 보여줌
# Out:
# <AxesSubplot:>
