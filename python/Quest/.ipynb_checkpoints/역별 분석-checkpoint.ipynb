# %% [markdown]
# ### 역별 분석

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.font_manager as fm
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
from PIL import Image

# %%
plt.rcParams['font.family']='HYGPRM'

# %%
df1=pd.read_csv("MetroData/2201.csv")
df2=pd.read_csv("MetroData/2202.csv")
df3=pd.read_csv("MetroData/2203.csv")
df4=pd.read_csv("MetroData/2204.csv")
df5=pd.read_csv("MetroData/2205.csv")
df6=pd.read_csv("MetroData/2206.csv")
df7=pd.read_csv("MetroData/2207.csv")
df8=pd.read_csv("MetroData/2208.csv")
df9=pd.read_csv("MetroData/2022.csv")

# %%
df9.역.unique()
# Out:
# array(['수서', '학여울', '대청', '일원', '창동', '신설동', '동대문', '종로5가', '서울역', '동묘앞',
#        '시청', '종각', '종로3가', '구로디지털단지', '신대방', '신림', '봉천', '서울대입구(관악구청)',
#        '낙성대(강감찬)', '사당', '방배', '서초', '교대(법원.검찰청)', '강남', '역삼', '선릉',
#        '삼성(무역센터)', '종합운동장', '잠실새내', '잠실(송파구청)', '잠실나루', '강변(동서울터미널)',
#        '구의(광진구청)', '건대입구', '성수', '뚝섬', '한양대', '왕십리(성동구청)', '상왕십리', '신당',
#        '동대문역사문화공원(DDP)', '을지로4가', '을지로3가', '을지로입구', '청량리(서울시립대입구)', '제기동',
#        '이대', '일산', '탄현', '복정', '신촌', '홍대입구', '합정', '당산', '영등포구청', '문래',
#        '신도림', '대림(구로구청)', '지평', '용문', '원덕', '양평', '오빈', '아신', '국수', '신원',
#        '양수', '운길산', '팔당', '도심', '덕소', '양정', '도농', '구리', '양원', '망우',
#        '상봉(시외버스터미널)', '중랑', '회기', '신창(순천향대)', '온양온천', '배방', '탕정', '아산',
#        '쌍용(나사렛대)', '봉명', '대화', '주엽', '정발산', '마두', '백석', '대곡', '화정', '원당',
#        '삼송', '원흥', '보문', '성신여대입구(돈암)', '정릉', '북한산보국문', '솔샘', '삼양사거리',
#        '삼양', '화계', '가오리', '4.19민주묘지', '솔밭공원', '북한산우이', '수리산', '오이도', '정왕',
#        '신길온천', '안산', '초지', '고잔', '중앙', '한대앞', '상록수', '반월', '대야미', '산본',
#        '인천', '신포', '숭의', '인하대', '송도', '연수', '원인재', '남동인더스파크', '호구포',
#        '인천논현', '소래포구', '월곶', '달월', '사리', '야목', '어천', '오목천', '고색', '매교',
#        '수원시청', '매탄권선', '망포', '영통', '청명', '상갈', '기흥', '신갈', '구성', '죽전',
#        '보정', '이매', '오리', '미금', '정자', '수내', '서현', '야탑', '모란', '태평', '가천대',
#        '선정릉', '강남구청', '압구정로데오', '서울숲', '수원', '대모산입구', '개포동', '구룡', '도곡',
#        '한티', '범계', '평촌', '인덕원', '정부과천청사', '과천', '대공원', '경마공원', '선바위',
#        '영종', '인천공항2터미널', '인천공항1터미널', '공항화물청사', '운서', '청라국제도시', '검암', '계양',
#        '김포공항', '마곡나루(서울식물원)', '디지털미디어시티', '공덕', '춘천', '남춘천', '김유정', '강촌',
#        '백양리', '굴봉산', '가평', '상천', '청평', '대성리', '마석', '천마산', '평내호평', '금곡',
#        '사릉', '퇴계원', '별내', '갈매', '신내', '도화', '중동', '온수(성공회대입구)', '도원',
#        '간석', '부개', '소사', '구일', '동인천', '제물포', '주안', '동암', '백운', '부평', '송내',
#        '부천', '역곡', '오류동', '개봉', '임진강', '문산', '파주', '월롱', '금촌', '금릉', '운정',
#        '야당', '풍산', '백마', '곡산', '능곡', '행신', '강매', '화전', '수색', '가좌', '서강대',
#        '효창공원앞', '소요산', '동두천', '보산', '동두천중앙', '지행', '덕정', '덕계', '양주', '녹양',
#        '가능', '의정부', '회룡', '망월사', '도봉산', '도봉', '방학', '녹천', '월계', '광운대',
#        '석계', '신이문', '외대앞', '응봉', '옥수', '한남', '서빙고', '이촌(국립중앙박물관)', '광명',
#        '서동탄', '당정', '천안', '두정', '직산', '성환', '평택', '평택지제', '서정리', '송탄',
#        '진위', '오산', '오산대', '세마', '병점', '세류', '독산', '화서', '성균관대', '의왕',
#        '군포', '금정', '명학', '안양', '관악', '석수', '금천구청', '가산디지털단지', '구로', '신길',
#        '영등포', '대방', '노량진', '용산', '남영', '여주', '세종대왕릉', '부발', '이천', '신둔도예촌',
#        '곤지암', '초월', '경기광주', '삼동', '판교', '중앙보훈병원', '둔촌오륜', '올림픽공원(한국체대)',
#        '한성백제', '송파나루', '석촌', '석촌고분', '삼전', '봉은사', '삼성중앙', '언주', '신논현',
#        '사평', '고속터미널', '신반포', '구반포', '동작(현충원)', '흑석(중앙대입구)', '노들', '샛강',
#        '여의도', '국회의사당', '선유도', '신목동', '염창', '등촌', '증미', '가양', '양천향교',
#        '신방화', '공항시장', '개화', '남위례', '수진', '신흥', '단대오거리',
#        '남한산성입구(성남법원.검찰청)', '산성', '장지', '문정', '가락시장', '송파', '몽촌토성(평화의문)',
#        '강동구청', '천호(풍납토성)', '암사', '부평구청', '굴포천', '부천시청', '신중동', '천왕',
#        '광명사거리', '철산', '남구로', '신풍', '보라매', '신대방삼거리', '장승배기', '상도',
#        '숭실대입구(살피재)', '남성', '이수', '내방', '반포', '논현', '학동', '청담', '뚝섬유원지',
#        '어린이대공원(세종대)', '군자(능동)', '중곡', '아현', '용마산(용마폭포공원)', '사가정', '면목',
#        '중화', '먹골', '태릉입구', '공릉(서울과학기술대)', '하계', '중계', '노원', '마들', '수락산',
#        '장암', '봉화산(서울의료원)', '화랑대(서울여대입구)', '돌곶이', '상월곡(한국과학기술연구원)',
#        '월곡(동덕여대)', '고려대(종암)', '안암(고대병원앞)', '창신', '청구', '약수', '버티고개',
#        '한강진', '이태원', '녹사평(용산구청)', '삼각지', '대흥(서강대앞)', '광흥창(서강)', '상수',
#        '망원', '마포구청', '월드컵경기장(성산)', '증산(명지대앞)', '새절(신사)', '구산', '독바위',
#        '불광', '역촌', '응암', '하남검단산', '하남시청(덕풍·신장)', '하남풍산', '미사', '강일', '마천',
#        '거여', '개롱', '오금', '방이', '둔촌동', '상일동', '고덕', '명일', '굽은다리(강동구민회관앞)',
#        '길동', '강동', '광나루(장신대)', '아차산(어린이대공원후문)', '장한평', '답십리', '마장', '행당',
#        '신금호', '광화문(세종문화회관)', '서대문', '충정로(경기대입구)', '애오개', '마포', '여의나루',
#        '영등포시장', '오목교(목동운동장앞)', '목동', '신정(은행정)', '까치산', '화곡', '우장산', '발산',
#        '마곡', '송정', '개화산', '방화', '쌍문', '상계', '당고개', '남태령', '총신대입구(이수)',
#        '신용산', '용답', '신답', '도림천', '양천구청', '신정네거리', '용두(동대문구청)', '지축',
#        '구파발', '연신내', '녹번', '홍제', '무악재', '독립문', '경복궁(정부서울청사)', '안국',
#        '동대입구', '금호', '압구정', '신사', '잠원', '남부터미널(예술의전당)', '양재(서초구청)', '매봉',
#        '대치', '숙대입구(갈월)', '회현(남대문시장)', '명동', '충무로', '혜화', '한성대입구(삼선교)',
#        '길음', '미아사거리', '미아(서울사이버대학)', '수유(강북구청)', '경찰병원', '까치울', '춘의',
#        '상동', '삼산체육관', '부천종합운동장', '보라매공원', '보라매병원', '당곡', '서원', '서울대벤처타운',
#        '관악산(서울대)', '서울지방병무청'], dtype=object)

# %% [markdown]
# ### 역별 승객 데이터

# %%
df9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).mean()
# Out:
#                    승차승객          하차승객          총 승객
# 역
# 4.19민주묘지    2835.794239   2648.514403   5484.308642
# 가능          5991.555556   5731.086420  11722.641975
# 가락시장        7059.563786   7350.170782  14409.734568
# 가산디지털단지    24495.405350  25609.767490  50105.172840
# 가양         17940.041152  17380.423868  35320.465021
# ...                 ...           ...           ...
# 회기         22136.893004  21401.835391  43538.728395
# 회룡         11207.921811  11094.000000  22301.921811
# 회현(남대문시장)  20525.320988  21529.827160  42055.148148
# 효창공원앞       4324.302469   4194.711934   8519.014403
# 흑석(중앙대입구)   7356.045267   7532.576132  14888.621399
#
# [529 rows x 3 columns]

# %%
df9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).sum()
# Out:
#                승차승객      하차승객      총 승객
# 역
# 4.19민주묘지     689098    643589   1332687
# 가능          1455948   1392654   2848602
# 가락시장        3430948   3572183   7003131
# 가산디지털단지    11904767  12446347  24351114
# 가양          4359430   4223443   8582873
# ...             ...       ...       ...
# 회기          5379265   5200646  10579911
# 회룡          2723525   2695842   5419367
# 회현(남대문시장)   4987653   5231748  10219401
# 효창공원앞       2101611   2038630   4140241
# 흑석(중앙대입구)   1787519   1830416   3617935
#
# [529 rows x 3 columns]

# %% [markdown]
# ### 많은 순으로 정렬

# %%
df9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).mean().sort_values(by="총 승객", ascending=False)
# Out:
#                      승차승객          하차승객           총 승객
# 역
# 강남           71148.094650  69960.296296  141108.390947
# 구로디지털단지      49118.683128  48950.687243   98069.370370
# 삼성(무역센터)     44035.452675  44269.156379   88304.609053
# 역삼           40589.000000  45437.427984   86026.427984
# 서울대입구(관악구청)  41717.621399  40957.534979   82675.156379
# ...                   ...           ...            ...
# 굴포천              1.206897      0.000000       1.206897
# 부평구청             1.185185      0.000000       1.185185
# 춘의               1.178571      0.000000       1.178571
# 부천종합운동장          1.111111      0.000000       1.111111
# 까치울              1.100000      0.000000       1.100000
#
# [529 rows x 3 columns]

# %%
df9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).sum().sort_values(by="총 승객", ascending=False)
# Out:
#               승차승객      하차승객      총 승객
# 역
# 잠실(송파구청)  19010542  19254739  38265281
# 강남        17288987  17000352  34289339
# 고속터미널     16712491  16651220  33363711
# 홍대입구      16095209  16956884  33052093
# 서울역       16402326  16425681  32828007
# ...            ...       ...       ...
# 굴포천             35         0        35
# 춘의              33         0        33
# 부평구청            32         0        32
# 삼산체육관           20         0        20
# 부천종합운동장         10         0        10
#
# [529 rows x 3 columns]

# %% [markdown]
# ### 상하위 20개씩 보기

# %%
df9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).mean().sort_values(by="총 승객", ascending=
9[["역", "노선", "승차승객", "하차승객", "총 승객"]].groupby(["역"]).sum().sort_values(by="총 승객", ascending=False).tail(20)
# Out:
#           승차승객   하차승객    총 승객
# 역
# 원덕       91711  87624  179335
# 세종대왕릉    77204  77154  154358
# 상천       77869  71019  148888
# 야목       83036  62524  145560
# 오빈       71379  70002  141381
# 신원       53976  45282   99258
# 굴봉산      41647  40285   81932
# 백양리      40087  35863   75950
# 달월       22317  15774   38091
# 지평       16018  17290   33308
# 임진강       7608   6040   13648
# 상동          56      0      56
# 부천시청        45      0      45
# 까치울         44      0      44
# 신중동         44      0      44
# 굴포천         35      0      35
# 춘의          33      0      33
# 부평구청        32      0      32
# 삼산체육관       20      0      20
# 부천종합운동장     10      0      10

# %% [markdown]
# ### 결과확인
# #### 총 승객 평균 정보
#  - 상위 역에는 2호선에 속해있는 역들이 많다
#  - 하위 역에는 7호선에 속해있는 역들이 많다
#  - 하위 9개 역의 총 승객 평균은 1점대이다
#  - 하위 9개 역은 하차 승객이 0이다
# #### 총 승객 합 정보
#  - 상위 역에는 2호선에 속해있는 역들이 많다
#  - 하위 역에는 7호선에 속해있는 역들이 많다
#  - 하위 9개 역의 총 승객 수는 100명이 안 된다
#  - 하위 9개 역은 하차 승객이 0이다
# #### 참고사항
#  - 총 승객 하위 역 중 하차 승객이 0인 역 중 일부는 환승역이어서 다른 노선으로 집계되기도 한다
#  - 7호선 일부 역들은 인천교통공사로 이관되어 서울시 데이터에 잡히지 않는다

# %% [markdown]
# ### 역별 카운트

# %%
df9.역.value_counts().sort_values(ascending=False)
# Out:
# 서울역          1215
# 공덕            972
# 김포공항          733
# 왕십리(성동구청)     729
# 종로3가          729
#              ...
# 굴포천            29
# 춘의             28
# 부평구청           27
# 삼산체육관          15
# 부천종합운동장         9
# Name: 역, Length: 529, dtype: int64

# %%
df9.역.value_counts().sort_values(ascending=False).head(30)
# Out:
# 서울역               1215
# 공덕                 972
# 김포공항               733
# 왕십리(성동구청)          729
# 종로3가               729
# 동대문역사문화공원(DDP)     729
# 디지털미디어시티           729
# 신설동                729
# 고속터미널              729
# 홍대입구               729
# 온수(성공회대입구)         486
# 옥수                 486
# 이촌(국립중앙박물관)        486
# 잠실(송파구청)           486
# 수원                 486
# 신촌                 486
# 천호(풍납토성)           486
# 신길                 486
# 불광                 486
# 인천                 486
# 가락시장               486
# 사당                 486
# 동대문                486
# 신당                 486
# 선릉                 486
# 건대입구               486
# 도봉산                486
# 종합운동장              486
# 마곡나루(서울식물원)        486
# 동묘앞                486
# Name: 역, dtype: int64

# %% [markdown]
# ### 환승역 개수 확인하기

# %%
station_cross = df9[['역','노선']].drop_duplicates().sort_values('역').reset_index(drop=True)
station_cross
# Out:
#              역     노선
# 0     4.19민주묘지  우이신설선
# 1           가능    경원선
# 2         가락시장    8호선
# 3         가락시장    3호선
# 4      가산디지털단지    7호선
# ..         ...    ...
# 616         회룡    경원선
# 617  회현(남대문시장)    4호선
# 618      효창공원앞    6호선
# 619      효창공원앞    경의선
# 620  흑석(중앙대입구)    9호선
#
# [621 rows x 2 columns]

# %%
s = station_cross.역.value_counts()
s[s>2]
# Out:
# 서울역               5
# 공덕                4
# 김포공항              4
# 홍대입구              3
# 디지털미디어시티          3
# 동대문역사문화공원(DDP)    3
# 왕십리(성동구청)         3
# 종로3가              3
# 신설동               3
# 고속터미널             3
# Name: 역, dtype: int64

# %% [markdown]
# ### 상위 5개역 확인

# %%
df9[df9['역'] == '서울역'].groupby(["노선"]).mean()
# Out:
#                   승차승객          하차승객          총 승객        승차-하차         월  \
# 노선
# 1호선       39586.860082  38310.020576  77896.880658  1276.839506  4.526749
# 4호선        9272.646091  15287.296296  24559.942387 -6014.650206  4.526749
# 경부선        7034.637860   2066.658436   9101.296296  4967.979424  4.526749
# 경의선        3418.707819   4277.572016   7696.279835  -858.864198  4.526749
# 공항철도 1호선   8186.432099   7653.847737  15840.279835   532.584362  4.526749
#
#                   일
# 노선
# 1호선       15.703704
# 4호선       15.703704
# 경부선       15.703704
# 경의선       15.703704
# 공항철도 1호선  15.703704

# %%
df9[df9['역'] == '공덕'].groupby(["노선"]).mean()
# Out:
#                   승차승객          하차승객          총 승객       승차-하차         월  \
# 노선
# 5호선       11461.197531  12077.213992  23538.411523 -616.016461  4.526749
# 6호선       15209.423868  14675.567901  29884.991770  533.855967  4.526749
# 경의선        3164.213992   2735.296296   5899.510288  428.917695  4.526749
# 공항철도 1호선   2027.094650   2721.736626   4748.831276 -694.641975  4.526749
#
#                   일
# 노선
# 5호선       15.703704
# 6호선       15.703704
# 경의선       15.703704
# 공항철도 1호선  15.703704

# %%
df9[df9['역'] == '김포공항'].groupby(["노선"]).mean()
# Out:
#                   승차승객          하차승객          총 승객        승차-하차         월  \
# 노선
# 5호선        7302.497942   7137.629630  14440.127572   164.868313  4.526749
# 9호선        7370.864198  11190.502058  18561.366255 -3819.637860  4.526749
# 경의선           1.250000      0.000000      1.250000     1.250000  4.750000
# 공항철도 1호선  11664.444444   6316.012346  17980.456790  5348.432099  4.526749
#
#                   일
# 노선
# 5호선       15.703704
# 9호선       15.703704
# 경의선       16.250000
# 공항철도 1호선  15.703704

# %%
df9[df9['역'] == '왕십리(성동구청)'].groupby(["노선"]).mean()
# Out:
#              승차승객          하차승객          총 승객        승차-하차         월  \
# 노선
# 2호선  14517.333333  12153.938272  26671.271605  2363.395062  4.526749
# 5호선   3988.460905   4642.884774   8631.345679  -654.423868  4.526749
# 경원선  13156.934156  14600.230453  27757.164609 -1443.296296  4.526749
#
#              일
# 노선
# 2호선  15.703704
# 5호선  15.703704
# 경원선  15.703704

# %%
df9[df9['역'] == '종로3가'].groupby(["노선"]).mean()
# Out:
#              승차승객          하차승객          총 승객        승차-하차         월  \
# 노선
# 1호선  22701.884774  20783.423868  43485.308642  1918.460905  4.526749
# 3호선   8390.168724  10008.510288  18398.679012 -1618.341564  4.526749
# 5호선  11793.547325  11649.506173  23443.053498   144.041152  4.526749
#
#              일
# 노선
# 1호선  15.703704
# 3호선  15.703704
# 5호선  15.703704

# %% [markdown]
# ### 결과
#  - 서울역이 가장 많이 등장
#  - 교차하는 노선이 많을수록 빈번하게 등장하며, 이는 환승역일수록 빈도수가 높다는 의미

# %% [markdown]
# ### 역별 그래프

# %%
plt.subplots(figsize=(18, 100))
sns.barplot(data=df9, x="총 승객", y="역")
plt.show()

# %%
plt.subplots(figsize=(12, 100))
sns.barplot(data=df9, x="승차-하차", y="역")
plt.show()
# Out:
# C:\Users\KB\miniconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ###
# 홍대입구            16095209  16956884  33052093
# 서울역             16402326  16425681  32828007
# 사당              13612957  13604198  27217155
# 선릉              13466324  13551353  27017677
# 신림              13400781  13008282  26409063
# 가산디지털단지         11904767  12446347  24351114
# 구로디지털단지         11935840  11895017  23830857
# 여의도             11127749  11207624  22335373
# 건대입구            10753431  11468587  22222018
# 신도림             11093283  11118199  22211482
# 삼성(무역센터)        10700615  10757405  21458020
# 역삼               9863127  11041295  20904422
# 종로3가            10421201  10313270  20734471
# 수원              10145310  10319837  20465147
# 서울대입구(관악구청)     10137382   9952681  20090063
# 합정               9808428  10224528  20032956
# 교대(법원.검찰청)       9533977   9385017  18918994
# 시청               9072433   8935451  18007884
# 영등포              8861918   9083983  17945901
# 노원               8299413   8988941  17288354
# 용산               8261591   8359391  16620982
# 청량리(서울시립대입구)     7995020   8086311  16081331
# 을지로입구            7956100   8121412  16077512
# 당산               7703172   8256009  15959181
# 양재(서초구청)         7565286   8237857  15803143
# 성수               7522402   8247067  15769469
# 공덕               7742449   7826985  15569434
# 신촌               7596269   7730829  15327098
# 왕십리(성동구청)        7694043   7629484  15323527
# 연신내              7811410   7388740  15200150
# 천호(풍납토성)         7210631   7640050  14850681
# 노량진              7413383   7272901  14686284
# 혜화               7230391   7302451  14532842
# 수유(강북구청)         7233145   7224928  14458073
# 부천               7151139   7183394  14334533
# 대림(구로구청)         6945713   7081495  14027208
# 종각               7106979   6873073  13980052
# 압구정              6689889   7150242  13840131
# 부평               6608071   7057795  13665866
# 수서               6675072   6791093  13466165
# 강변(동서울터미널)       6869661   6582947  13452608
# 신논현              6711422   6655504  13366926
# 을지로3가            6599140   6644631  13243771
# 신사               6366798   6668996  13035794
# 동대문역사문화공원(DDP)   6415515   6550850  12966365
# 동대문              6458792   6436058  12894850
# 광화문(세종문화회관)      6099303   6350319  12449622

# %% [markdown]
# ### 상위 역 별 그래프

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test2, x="총 승객", y=test2.index)
plt.show()

# %%
test1.index
# Out:
# Index(['강남', '구로디지털단지', '삼성(무역센터)', '역삼', '서울대입구(관악구청)', '잠실(송파구청)', '신림',
#        '영등포', '용산', '을지로입구', '양재(서초구청)', '성수', '혜화', '수유(강북구청)', '부천', '종각',
#        '압구정', '부평', '사당', '선릉', '강변(동서울터미널)', '신논현', '신사', '광화문(세종문화회관)',
#        '남부터미널(예술의전당)', '가산디지털단지', '까치산', '쌍문', '역곡', '화곡', '낙성대(강감찬)', '미아사거리',
#        '금정', '송내', '야탑', '범계', '여의도', '고속터미널', '건대입구', '신도림', '신대방', '홍대입구',
#        '서현', '회기', '인덕원', '수원', '회현(남대문시장)', '안양', '합정', '연신내'],
#       dtype='object', name='역')

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test1, x="총 승객", y=test1.index)
plt.show()

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test1, x="승차승객", y=test1.index)
plt.show()

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test1, x="하차승객", y=test1.index)
plt.show()

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test2, x="승차승객", y=test2.index)
plt.show()

# %%
plt.subplots(figsize=(15, 12))
sns.barplot(data=test2, x="하차승객", y=test2.index)
plt.show()

# %% [markdown]
# ### 그래프 확인
#  - 평균값의 그래프보다 합의 그래프가 상대적으로 고르게 분포되어 있다

# %% [markdown]
# ### 역별 승객 그래프

# %%
plt.subplots(figsize=(50, 5))
sns.lineplot(data=test1, x=test1.index, y="총 승객")
plt.show()

# %%
plt.subplots(figsize=(50, 5))
sns.lineplot(data=test1, x=test1.index, y="승차승객")
plt.show()

# %%
plt.subplots(figsize=(50, 5))
sns.lineplot(data=test1, x=test1.index, y="하차승객")
plt.show()

# %% [markdown]
# ### 월별 총 승객 상위 역

# %% [markdown]
# #### 총 승객 상위 역 25곳 구하기

# %%
df9.groupby(["역"]).sum().sort_values(by="총 승객", ascending=False)[["총 승객"]].head(25)
# Out:
#                   총 승객
# 역
# 잠실(송파구청)      38265281
# 강남            34289339
# 고속터미널         33363711
# 홍대입구          33052093
# 서울역           32828007
# 사당            27217155
# 선릉            27017677
# 신림            26409063
# 가산디지털단지       24351114
# 구로디지털단지       23830857
# 여의도           22335373
# 건대입구          22222018
# 신도림           22211482
# 삼성(무역센터)      21458020
# 역삼            20904422
# 종로3가          20734471
# 수원            20465147
# 서울대입구(관악구청)   20090063
# 합정            20032956
# 교대(법원.검찰청)    18918994
# 시청            18007884
# 영등포           17945901
# 노원            17288354
# 용산            16620982
# 청량리(서울시립대입구)  16081331

# %%
top25_station=df9.groupby(["역"]).sum().sort_values(by="총 승객", ascending=False)[["총 승객"]].head(25).index
top25_station
# Out:
# Index(['잠실(송파구청)', '강남', '고속터미널', '홍대입구', '서울역', '사당', '선릉', '신림', '가산디지털단지',
#        '구로디지털단지', '여의도', '건대입구', '신도림', '삼성(무역센터)', '역삼', '종로3가', '수원',
#        '서울대입구(관악구청)', '합정', '교대(법원.검찰청)', '시청', '영등포', '노원', '용산',
#        '청량리(서울시립대입구)'],
#       dtype='object', name='역')

# %%
top25_station_cond=df9["역"].isin(top25_station)
top25_station_cond
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145789    False
# 145790    False
# 145791    False
# 145792    False
# 145793    False
# Name: 역, Length: 145794, dtype: bool

# %%
top25=df9[top25_station_cond]
top25
# Out:
#                 날짜        노선        역   승차승객   하차승객   총 승객  승차-하차  월   일 요일
# 8       2022-01-01       1호선      서울역  18398  16926  35324   1472  1   1  토
# 10      2022-01-01       1호선       시청   5604   5006  10610    598  1   1  토
# 12      2022-01-01       1호선     종로3가  11017   9630  20647   1387  1   1  토
# 13      2022-01-01       2호선  구로디지털단지  18363  18352  36715     11  1   1  토
# 15      2022-01-01       2호선       신림  29564  29162  58726    402  1   1  토
# ...            ...       ...      ...    ...    ...    ...    ... ..  .. ..
# 145647  2022-08-31  공항철도 1호선      서울역   9501   8471  17972   1030  8  31  수
# 145649  2022-08-31  공항철도 1호선     홍대입구  11087  11545  22632   -458  8  31  수
# 145669  2022-08-31       분당선       선릉  14565  21822  36387  -7257  8  31  수
# 145676  2022-08-31       분당선       수원   8372   6897  15269   1475  8  31  수
# 145728  2022-08-31       신림선       신림   1607   2204   3811   -597  8  31  수
#
# [11760 rows x 10 columns]

# %% [markdown]
# #### 상위 역 25개가 속해있는 노선

# %%
top25.노선.unique()
# Out:
# array(['1호선', '2호선', '분당선', '공항철도 1호선', '경의선', '경원선', '경부선', '9호선', '8호선',
#        '7호선', '6호선', '5호선', '4호선', '3호선', '신림선'], dtype=object)

# %%
top25.groupby("노선").sum().sort_values(by="총 승객", ascending=False)[["총 승객"]]
# Out:
#                총 승객
# 노선
# 2호선       316925409
# 경부선        63131791
# 1호선        47405460
# 7호선        37742970
# 3호선        29010952
# 4호선        24845913
# 9호선        17801844
# 5호선        17150626
# 분당선         9838150
# 공항철도 1호선    8819860
# 경원선         7322160
# 8호선         6961678
# 6호선         5850424
# 경의선         2789012
# 신림선          345446

# %% [markdown]
# #### 상위 25개 역의 노선 중 상위 5개 노선 구하기

# %%
top25.groupby("노선").sum().sort_values(by="총 승객", ascending=False)[["총 승객"]].head(5)
# Out:
#           총 승객
# 노선
# 2호선  316925409
# 경부선   63131791
# 1호선   47405460
# 7호선   37742970
# 3호선   29010952

# %%
top5_line=top25.groupby("노선").sum().sort_values(by="총 승객", ascending=False)[["총 승객"]].head(5).index
top5_line
# Out:
# Index(['2호선', '경부선', '1호선', '7호선', '3호선'], dtype='object', name='노선')

# %%
top5_line_cond=df9["노선"].isin(top5_line)
top5_line_cond
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 145789    False
# 145790    False
# 145791    False
# 145792    False
# 145793    False
# Name: 노선, Length: 145794, dtype: bool

# %% [markdown]
# #### 상위 25개 역과 상위 5개 노선 결합

# %%
top=df9[top25_station_cond & top5_line_cond]
top
# Out:
#                 날짜   노선        역   승차승객   하차승객   총 승객  승차-하차  월   일 요일
# 8       2022-01-01  1호선      서울역  18398  16926  35324   1472  1   1  토
# 10      2022-01-01  1호선       시청   5604   5006  10610    598  1   1  토
# 12      2022-01-01  1호선     종로3가  11017   9630  20647   1387  1   1  토
# 13      2022-01-01  2호선  구로디지털단지  18363  18352  36715     11  1   1  토
# 15      2022-01-01  2호선       신림  29564  29162  58726    402  1   1  토
# ...            ...  ...      ...    ...    ...    ...    ... ..  .. ..
# 145516  2022-08-31  경부선       용산  36725  37759  74484  -1034  8  31  수
# 145519  2022-08-31  경부선      영등포  39567  40820  80387  -1253  8  31  수
# 145520  2022-08-31  경부선      신도림   4427   4459   8886    -32  8  31  수
# 145523  2022-08-31  경부선  가산디지털단지  19472  22678  42150  -3206  8  31  수
# 145534  2022-08-31  경부선       수원  37197  39373  76570  -2176  8  31  수
#
# [7776 rows x 10 columns]

# %%
top.sort_values(by="총 승객", ascending=False)
# Out:
#                 날짜   노선           역    승차승객    하차승객    총 승객  승차-하차  월   일 요일
# 58995   2022-04-09  2호선    잠실(송파구청)  122543  118237  240780   4306  4   9  토
# 79176   2022-05-13  2호선          강남   95342   98137  193479  -2795  5  13  금
# 82888   2022-05-20  2호선          강남   95179   98286  193465  -3107  5  20  금
# 116915  2022-07-15  2호선          강남   96795   96558  193353    237  7  15  금
# 75064   2022-05-06  2호선    잠실(송파구청)   97288   95576  192864   1712  5   6  금
# ...            ...  ...         ...     ...     ...     ...    ... ..  .. ..
# 17530   2022-01-30  경부선         신도림    1819    1505    3324    314  1  30  일
# 321     2022-01-01  경부선         신도림    1490    1275    2765    215  1   1  토
# 18953   2022-02-01  경부선         신도림    1359    1305    2664     54  2   1  화
# 18135   2022-01-31  경부선         신도림    1389    1182    2571    207  1  31  월
# 18758   2022-02-01  3호선  교대(법원.검찰청)    1449     997    2446    452  2   1  화
#
# [7776 rows x 10 columns]

# %% [markdown]
# #### 상위 25개 역의 월별 총 승객 수

# %%
month_top=top.pivot_table(index="월", columns="역", values="총 승객")
month_top
# Out:
# 역       가산디지털단지             강남          건대입구         고속터미널    교대(법원.검찰청)  \
# 월
# 1  48587.887097  140046.612903  42505.016129  50003.500000  36280.290323
# 2  45137.178571  128262.821429  39300.339286  46510.428571  33944.125000
# 3  46057.193548  125027.064516  41509.935484  44173.854839  34828.935484
# 4  51919.583333  143798.800000  48362.050000  54316.583333  40238.100000
# 5  53113.741935  151591.322581  51905.419355  61968.387097  42570.548387
# 6  52802.100000  146197.533333  48429.233333  59985.483333  42181.850000
# 7  52252.951613  152091.838710  47790.838710  60341.677419  41294.903226
# 8  50635.500000  140858.967742  45542.370968  57392.709677  39749.935484
#
# 역        구로디지털단지            노원            사당       삼성(무역센터)   서울대입구(관악구청)  \
# 월
# 1   93925.548387  33571.741935  63003.032258   82130.193548  77890.774194
# 2   87935.321429  31988.214286  59107.535714   75705.107143  74208.500000
# 3   88651.774194  32111.612903  60258.838710   74310.580645  77404.419355
# 4   99938.433333  35636.066667  72240.700000   85671.600000  86670.966667
# 5  104746.419355  38403.483871  78781.322581   92969.419355  90625.870968
# 6  104675.600000  37535.033333  78253.333333   97120.600000  86271.100000
# 7  103647.580645  38293.774194  75767.193548  102367.838710  85625.129032
# 8  100326.967742  36570.838710  71206.774194   95141.677419  82130.032258
#
# 역  ...           신도림             신림            역삼           영등포            용산  \
# 월  ...
# 1  ...  42397.064516  104728.838710  83323.193548  68113.580645  60289.096774
# 2  ...  40164.214286  100276.642857  76228.964286  63825.571429  55460.714286
# 3  ...  40642.741935  101544.548387  75427.096774  63353.064516  53824.258065
# 4  ...  47584.216667  113709.066667  85905.433333  74133.333333  65033.300000
# 5  ...  50523.854839  118474.645161  90154.451613  81111.064516  77505.032258
# 6  ...  49713.733333  109221.700000  92652.266667  80753.166667  77450.766667
# 7  ...  48029.677419  107071.290323  92616.935484  81603.806452  79784.451613
# 8  ...  46219.709677  102630.612903  91164.774194  77179.451613  76776.516129
#
# 역       잠실(송파구청)          종로3가  청량리(서울시립대입구)            합정           홍대입구
# 월
# 1  118075.064516  28721.354839  34754.451613  54227.387097  101347.000000
# 2  106530.785714  27030.732143  31312.250000  50520.964286   94077.392857
# 3  104659.451613  27170.209677  32864.451613  51123.258065   94844.870968
# 4  144153.466667  31839.983333  37461.766667  59880.200000  109695.300000
# 5  140976.548387  34367.887097  39901.612903  64149.322581  125208.387097
# 6  135699.666667  33785.016667  38321.166667  62537.200000  119819.166667
# 7  143558.129032  33087.290323  37146.838710  62996.161290  126913.225806
# 8  135477.483871  31275.645161  36266.193548  60904.612903  120815.677419
#
# [8 rows x 24 columns]

# %%
plt.subplots(figsize=(7, 6))
sns.heatmap(month_top, cmap='Blues')
# Out:
# <AxesSubplot:xlabel='역', ylabel='월'>

# %% [markdown]
# ### 결과확인
#  - 강남과 잠실(송파구청)역의 총 승객이 눈에 띄게 많다는 것을 알 수 있다
#  - 교대(법원,검찰청)역과 노원역, 시청역, 종로3가, 청량리(서울시립대입구)역은 상대적으로 승객이 적은 것을 알 수 있다
#  - 25곳의 역 모두 2~3월 승객의 수가 적고, 5월과 7월이 승객의 수가 많다는 것을 알 수 있다

# %% [markdown]
# ### 상위역 월별 히트맵
#  - 1월, 5월

# %%
top_jan=top[top['월']==1]
top_jan
# Out:
#                날짜   노선             역   승차승객   하차승객   총 승객  승차-하차  월   일 요일
# 8      2022-01-01  1호선           서울역  18398  16926  35324   1472  1   1  토
# 10     2022-01-01  1호선            시청   5604   5006  10610    598  1   1  토
# 12     2022-01-01  1호선          종로3가  11017   9630  20647   1387  1   1  토
# 13     2022-01-01  2호선       구로디지털단지  18363  18352  36715     11  1   1  토
# 15     2022-01-01  2호선            신림  29564  29162  58726    402  1   1  토
# ...           ...  ...           ...    ...    ...    ...    ... ..  .. ..
# 18455  2022-01-31  2호선            시청   2790   2247   5037    543  1  31  월
# 18456  2022-01-31  1호선  청량리(서울시립대입구)   9670  10051  19721   -381  1  31  월
# 18460  2022-01-31  1호선          종로3가   8629   7556  16185   1073  1  31  월
# 18463  2022-01-31  1호선           서울역  15649  16857  32506  -1208  1  31  월
# 18466  2022-01-31  1호선            시청   4315   4155   8470    160  1  31  월
#
# [992 rows x 10 columns]

# %%
top_jan_day_station=top_jan.pivot_table("총 승객", index="일", columns="역")
top_jan_day_station
# Out:
# 역   가산디지털단지        강남     건대입구    고속터미널  교대(법원.검찰청)   구로디지털단지       노원  \
# 일
# 1   12830.5   51177.0  28784.0  27172.0      8981.5   36715.0  16039.0
# 2   13335.5   56459.0  30579.0  44759.0     11480.5   39697.0  20556.0
# 3   66208.5  162691.0  44122.5  47910.5     42938.5  116038.0  37957.0
# 4   67297.0  168327.0  45261.5  47970.0     45392.5  118288.0  38992.0
# 5   67006.0  167770.0  46036.5  49019.0     45751.5  118788.0  38558.0
# 6   67577.0  171091.0  46572.0  50033.5     46337.0  119682.0  38866.0
# 7   66090.0  179869.0  49821.0  57938.5     47449.5  120694.0  41056.0
# 8   19640.5  120295.0  44211.0  54615.0     21903.0   64310.0  30879.0
# 9   13789.5   66224.0  31961.0  42552.0     13031.0   43462.0  20800.0
# 10  68205.5  171768.0  45933.5  49336.5     47224.5  119954.0  39083.0
# 11  68181.0  176415.0  46191.0  49585.5     48598.5  120397.0  39296.0
# 12  66663.0  173245.0  46538.5  49346.5     48375.5  118588.0  38064.0
# 13  66776.5  174976.0  47529.0  51100.5     48531.0  118971.0  38408.0
# 14  65074.5  182022.0  49599.0  59777.0     48716.0  119309.0  40336.0
# 15  19798.0  122092.0  44626.5  56115.0     22318.5   64412.0  30397.0
# 16  14134.0   67912.0  33732.5  44845.5     13604.5   44291.0  20546.0
# 17  68055.5  174514.0  46157.5  49837.0     47970.0  119586.0  39287.0
# 18  68324.0  177533.0  46588.5  50537.0     49361.5  121058.0  40353.0
# 19  69655.5  177997.0  47583.0  51923.0     51008.5  122296.0  40038.0
# 20  67675.0  176621.0  47762.5  52425.5     50166.0  121075.0  39203.0
# 21  65896.0  184099.0  51320.0  59970.5     50882.5  120557.0  42068.0
# 2   67054.0  137228.0  35026.0       41595.0  62015.0  110137.0
# 3   67772.0  149559.0  36639.0       42822.0  65686.0  117913.0
# 4   88165.0  178162.0  39553.0       44453.0  72294.0  137312.0
# 5   79493.0  124618.0  28078.5       34660.0  56793.0  152416.0
# 6   91656.0  192864.0  38902.5       43001.0  72697.0  158850.0
# 7   86276.0  134334.0  28705.5       37030.0  58620.0  143924.0
# 8   71560.0   93258.0  17045.5       26094.0  37971.0   91754.0
# 9   75132.0  139109.0  36052.5       41097.0  62874.0  111222.0
# 10  72274.0  141334.0  36998.0       42700.0  66290.0  115878.0
# 11  71181.0  143647.0  37860.5       42645.0  66888.0  119168.0
# 12  74116.0  146505.0  38235.0       42859.0  68649.0  120199.0
# 13  89940.0  161521.0  40990.5       44179.0  76077.0  139762.0
# 14  91139.0  150616.0  35598.0       40917.0  75912.0  169154.0
# 15  76832.0  109685.0  22218.0       29445.0  53595.0  121630.0
# 16  72939.0  138377.0  37025.0       41901.0  63091.0  113742.0
# 17  71280.0  143517.0  37532.0       42697.0  65218.0  114700.0
# 18  70828.0  140706.0  37158.0       41001.0  65369.0  115534.0
# 19  74392.0  145682.0  38448.5       43455.0  68124.0  119439.0
# 20  88469.0  167071.0  41681.5       45583.0  74854.0  139094.0
# 21  91329.0  148919.0  36330.0       41693.0  70381.0  159850.0
# 22  74653.0  106498.0  22177.5       29262.0  49931.0  111530.0
# 23  71821.0  133178.0  35967.5       41575.0  62828.0  110328.0
# 24  69587.0  141530.0  36970.0       42189.0  65534.0  113334.0
# 25  71241.0  143989.0  37347.0       43249.0  66429.0  116671.0
# 26  74793.0  145053.0  38257.0       43233.0  67780.0  119893.0
# 27  89031.0  163195.0  41080.5       44830.0  75664.0  134295.0
# 28  91065.0  145877.0  35489.5       40588.0  69143.0  152205.0
# 29  72885.0  103591.0  20926.5       28109.0  48106.0  107333.0
# 30  69996.0  132895.0  35138.0       40294.0  61695.0  107437.0
# 31  76989.0  153573.0  39337.0       45157.0  70421.0  122957.0
#
# [31 rows x 24 columns]

# %%
plt.subplots(figsize=(9, 9))
sns.heatmap(top_jan_day_station ,cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='역', ylabel='일'>

# %% [markdown]
# ### 결과
# #### 1월
#  - 주중이 색상이 진하게 표시되며, 주말일수록 색상이 연하다
#  - 주중은 승객이 많고, 주말은 승객이 적다는 것을 직관적으로 표현하고 있다
#  - 다만, 강남과 잠심(송파구청)은 주말이어도 승객이 많다는 것을 알 수 있다
#  - 29~31일이 색상이 연한 것은 설 연휴와 주말이 겹친 영향으로 볼 수 있다
#  - 홍대입구는 전반적으로 승객의 분포가 고르다는 것을 알 수 있다
# #### 5월
#  - 주중이 색상이 진하며, 주말일수록 색상이 연하다
#  - 주중에 승객이 많고, 주말에 적다
#  - 다만, 5월은 전체적으로 화~토요일에 승객이 많고, 일요일과 월요일 승객이 적다
#  - 홍대입구는 전반적으로 승객의 분포가 고르다는 것을 알 수 있다

# %% [markdown]
# ### 노선별 역의 승객 데이터
#  - 1호선~ 6호선까지만

# %% [markdown]
# #### 1호선

# 남부터미널(예술의전당)  15.703704
# 녹번            15.703704
# 대청            15.703704
# 대치            15.703704
# 도곡            15.703704
# 독립문           15.703704
# 동대입구          15.703704
# 매봉            15.703704
# 무악재           15.703704
# 불광            15.703704
# 수서            15.703704
# 신사            15.703704
# 안국            15.703704
# 압구정           15.703704
# 약수            15.703704
# 양재(서초구청)      15.703704
# 연신내           15.703704
# 오금            15.703704
# 옥수            15.703704
# 을지로3가         15.703704
# 일원            15.703704
# 잠원            15.703704
# 종로3가          15.703704
# 지축            15.703704
# 충무로           16.240260
# 학여울           15.703704
# 홍제            15.703704

# %%
plt.subplots(figsize=(10, 8))
sns.barplot(data=line3, x="총 승객", y=line3.index)
plt.show()

# %% [markdown]
# #### 4호선

# %%
line4=df9[df9.노선=="4호선"].groupby(["역"]).mean()
line4
# Out:
#                         승차승객          하차승객          총 승객        승차-하차  \
# 역
# 길음              17950.238683  17592.065844  35542.304527   358.172840
# 남태령              1130.716049    937.275720   2067.991770   193.440329
# 노원              16760.769547  18836.168724  35596.938272 -2075.399177
# 당고개              9041.975309   8241.884774  17283.860082   800.090535
# 동대문             16339.160494  16751.781893  33090.942387  -412.621399
# 동대문역사문화공원(DDP)  13184.316872  11906.814815  25091.131687  1277.502058
# 동작(현충원)          1429.473251   1583.176955   3012.650206  -153.703704
# 명동              17296.975309  18062.975309  35359.950617  -766.000000
# 미아(서울사이버대학)     13004.127572  12523.971193  25528.098765   480.156379
# 미아사거리           24057.584362  23341.641975  47399.226337   715.942387
# 사당              22739.884774  19349.790123  42089.674897  3390.094650
# 삼각지              4482.053498   5223.748971   9705.802469  -741.695473
# 상계              16693.621399  15529.024691  32222.646091  1164.596708
# 서울역              9272.646091  15287.296296  24559.942387 -6014.650206
# 성신여대입구(돈암)      18024.049383  17339.773663  35363.823045   684.275720
# 수유(강북구청)        29766.028807  29732.213992  59498.242798    33.814815
# 숙대입구(갈월)        11687.621399  11322.987654  23010.609053   364.633745
# 신용산             14428.946502  15206.559671  29635.506173  -777.613169
# 쌍문              25239.065844  23214.810700  48453.876543  2024.255144
# 이촌(국립중앙박물관)      7611.654321   8339.551440  15951.205761  -727.897119
# 창동              22515.934156  23742.065844  46258.000000 -1226.131687
# 총신대입구(이수)       16485.946502  17861.279835  34347.226337 -1375.333333
# 충무로             21534.707819  22480.382716  44015.090535  -945.674897
# 한성대입구(삼선교)      11975.004115  11699.806584  23674.810700   275.197531
# 혜화              29754.695473  30051.238683  59805.934156  -296.543210
# 회현(남대문시장)       20525.320988  21529.827160  42055.148148 -1004.506173
#
#                        월          일
# 역
# 길음              4.526749  15.703704
# 남태령             4.526749  15.703704
# 노원              4.526749  15.703704
# 당고개             4.526749  15.703704
# 동대문             4.526749  15.703704
# 동대문역사문화공원(DDP)  4.526749  15.703704
# 동작(현충원)         4.526749  15.703704
# 명동              4.526749  15.703704
# 미아(서울사이버대학)     4.526749  15.703704
# 미아사거리           4.526749  15.703704
# 사당              4.526749  15.703704
# 삼각지             4.526749  15.703704
# 상계              4.526749  15.703704
# 서울역             4.526749  15.703704
# 영등포구청            3270.312757   3311.596708   6581.909465   -41.283951
# 영등포시장            8919.074074   9204.679012  18123.753086  -285.604938
# 오금               3125.366255   3118.921811   6244.288066     6.444444
# 오목교(목동운동장앞)     18856.456790  20008.633745  38865.090535 -1152.176955
# 올림픽공원(한국체대)      3931.069959   3464.300412   7395.370370   466.769547
# 왕십리(성동구청)        3988.460905   4642.884774   8631.345679  -654.423868
# 우장산             12486.510288  12301.954733  24788.465021   184.555556
# 을지로4가            4981.263374   5126.650206  10107.913580  -145.386831
# 장한평             15529.041152  15384.279835  30913.320988   144.761317
# 종로3가            11793.547325  11649.506173  23443.053498   144.041152
# 천호(풍납토성)        16621.934156  16390.753086  33012.687243   231.181070
# 청구               3401.172840   3098.156379   6499.329218   303.016461
# 충정로(경기대입구)       3739.399177   3767.987654   7507.386831   -28.588477
# 하남검단산            5382.991770   5189.872428  10572.864198   193.119342
# 하남시청(덕풍·신장)      6108.325103   5905.695473  12014.020576   202.629630
# 하남풍산             3667.761317   3640.148148   7307.909465    27.613169
# 행당               6969.386831   6185.860082  13155.246914   783.526749
# 화곡              24629.090535  22903.251029  47532.341564  1725.839506
#
#                        월          일
# 역
# 강동              4.526749  15.703704
# 강일              4.526749  15.703704
# 개롱              4.526749  15.703704
# 개화산             4.526749  15.703704
# 거여              4.526749  15.703704
# 고덕              4.526749  15.703704
# 공덕              4.526749  15.703704
# 광나루(장신대)        4.526749  15.703704
# 광화문(세종문화회관)     4.526749  15.703704
# 군자(능동)          4.526749  15.703704
# 굽은다리(강동구민회관앞)   4.526749  15.703704
# 길동              4.526749  15.703704
# 김포공항            4.526749  15.703704
# 까치산             4.526749  15.703704
# 답십리             4.526749  15.703704
# 동대문역사문화공원(DDP)  4.526749  15.703704
# 둔촌동             4.526749  15.703704
# 마곡              4.526749  15.703704
# 마장              4.526749  15.703704
# 마천              4.526749  15.703704
# 마포              4.526749  15.703704
# 명일              4.526749  15.703704
# 목동              4.526749  15.703704
# 미사              4.526749  15.703704
# 발산              4.526749  15.703704
# 방이              4.526749  15.703704
# 방화              4.526749  15.703704
# 상일동             4.526749  15.703704
# 서대문             4.526749  15.703704
# 송정              4.526749  15.703704
# 신금호             4.526749  15.703704
# 신길              4.526749  15.703704
# 신정(은행정)         4.526749  15.703704
# 아차산(어린이대공원후문)   4.526749  15.703704
# 애오개             4.526749  15.703704
# 양평              4.526749  15.703704
# 여의나루            4.526749  15.703704
# 여의도             4.526749  15.703704
# 영등포구청           4.526749  15.703704
# 영등포시장           4.526749  15.703704
# 오금              4.526749  15.703704
# 오목교(목동운동장앞)     4.526749  15.703704
# 올림픽공원(한국체대)     4.526749  15.703704
# 왕십리(성동구청)       4.526749  15.703704
# 우장산             4.526749  15.703704
# 을지로4가           4.526749  15.703704
# 장한평             4.526749  15.703704
# 종로3가            4.526749  15.703704
# 천호(풍납토성)        4.526749  15.703704
# 청구              4.526749  15.703704
# 충정로(경기대입구)      4.526749  15.703704
# 하남검단산           4.526749  15.703704
# 하남시청(덕풍·신장)     4.526749  15.703704
# 하남풍산            4.526749  15.703704
# 행당              4.526749  15.703704
# 화곡              4.526749  15.703704

# %%
plt.subplots(figsize=(12, 10))
sns.barplot(data=line5, x="총 승객", y=line5.index)
plt.show()

# %% [markdown]
# #### 6호선

# %%
line6=df9[df9.노선=="6호선"].groupby(["역"]).mean()
line6
# Out:
#                         승차승객          하차승객          총 승객        승차-하차  \
# 역
# 고려대(종암)          7069.934156   6862.757202  13932.691358   207.176955
# 공덕              15209.423868  14675.567901  29884.991770   533.855967
# 광흥창(서강)          7689.576132   7410.555556  15100.131687   279.020576
# 구산               6676.189300   4998.547325  11674.736626  1677.641975
# 녹사평(용산구청)        4580.880658   4682.382716   9263.263374  -101.502058
# 대흥(서강대앞)         7128.041152   7319.423868  14447.465021  -191.382716
# 독바위              2390.839506   2558.485597   4949.325103  -167.646091
# 돌곶이              8169.259259   7571.621399  15740.880658   597.637860
# 동묘앞              7255.641975   7291.049383  14546.691358   -35.407407
# 디지털미디어시티        11556.958848  12519.358025  24076.316872  -962.399177
# 마포구청            12275.300412  10999.094650  23274.395062  1276.205761
# 망원              12732.094650  13673.687243  26405.781893  -941.592593
# 버티고개             1808.637860   1835.650206   3644.288066   -27.012346
# 보문               6453.275720   5885.831276  12339.106996   567.444444
# 봉화산(서울의료원)       7487.728395   7097.460905  14585.189300   390.267490
# 불광               3959.995885   3827.329218   7787.325103   132.666667
# 삼각지              6140.012346   5185.370370  11325.382716   954.641975
# 상수               8084.720165   9280.790123  17365.510288 -1196.069959
# 상월곡(한국과학기술연구원)   5441.580247   4910.901235  10352.481481   530.679012
# 새절(신사)          11032.987654  10313.576132  21346.563786   719.411523
# 석계              10657.320988  11044.621399  21701.942387  -387.300412
# 신내                  1.285714      0.000000      1.285714     1.285714
# 신당               7116.423868   7313.181070  14429.604938  -196.757202
# 안암(고대병원앞)        9856.716049   9909.534979  19766.251029   -52.818930
# 약수               3106.078189   3118.580247   6224.658436   -12.502058
# 역촌               3293.716049   3806.991770   7100.707819  -513.275720
# 연신내                 1.618321      0.000000      1.618321     1.618321
# 월곡(동덕여대)        10042.222222   9833.456790  19875.679012   208.765432
# 월드컵경기장(성산)       4717.781893   5137.724280   9855.506173  -419.942387
# 응암              15252.646091  15104.156379  30356.802469   148.489712
# 이태원             10634.909465  11498.037037  22132.946502  -863.127572
# 증산(명지대앞)         8780.320988   8722.028807  17502.349794    58.292181
# 창신               3006.411523   2509.748971   5516.160494   496.662551
# 청구               3137.403292   3274.794239   6412.197531  -137.390947
# 태릉입구             4990.893004   5448.600823  10439.493827  -457.707819
# 한강진              7592.938272   8880.646091  16473.584362 -1287.707819
# 합정              12214.572016  11861.246914  24075.818930   353.325103
# 화랑대(서울여대입구)      9961.251029   7859.748971  17821.000000  2101.502058
# 효창공원앞            6109.411523   5537.798354  11647.209877   571.613169
#
#                        월          일
# 역
# 고려대(종암)         4.526749  15.703704
# 공덕              4.526749  15.703704
# 광흥창(서강)         4.526749  15.703704
# 구산              4.526749  15.703704
# 녹사평(용산구청)       4.526749  15.703704
# 대흥(서강대앞)        4.526749  15.703704
# 독바위             4.526749  15.703704
# 돌곶이             4.526749  15.703704
# 동묘앞             4.526749  15.703704
# 디지털미디어시티        4.526749  15.703704
# 마포구청            4.526749  15.703704
# 망원              4.526749  15.703704
# 버티고개            4.526749  15.703704
# 보문              4.526749  15.703704
# 봉화산(서울의료원)      4.526749  15.703704
# 불광              4.526749  15.703704
# 삼각지             4.526749  15.703704
# 상수              4.526749  15.703704
# 상월곡(한국과학기술연구원)  4.526749  15.703704
# 새절(신사)          4.526749  15.703704
# 석계              4.526749  15.703704
# 신내              5.017857  16.089286
# 신당              4.526749  15.703704
# 안암(고대병원앞)       4.526749  15.703704
# 약수              4.526749  15.703704
# 역촌              4.526749  15.703704
# 연신내             4.671756  15.557252
# 월곡(동덕여대)        4.526749  15.703704
# 월드컵경기장(성산)      4.526749  15.703704
# 응암              4.526749  15.703704
# 이태원             4.526749  15.703704
# 증산(명지대앞)        4.526749  15.703704
# 창신              4.526749  15.703704
# 청구              4.526749  15.703704
# 태릉입구            4.526749  15.703704
# 한강진             4.526749  15.703704
# 합정              4.526749  15.703704
# 화랑대(서울여대입구)     4.526749  15.703704
# 효창공원앞           4.526749  15.703704

# %%
plt.subplots(figsize=(10, 8))
sns.barplot(data=line6, x="총 승객", y=line6.index)
plt.show()

# %% [markdown]
# ### 워드 클라우드로 표현

# %%
station_name = np.sort(df9.역.unique())
station_code = pd.DataFrame(list(enumerate(station_name)), columns=['역코드','역'])
station_code
# Out:
#      역코드          역
# 0      0   4.19민주묘지
# 1      1         가능
# 2      2       가락시장
# 3      3    가산디지털단지
# 4      4         가양
# ..   ...        ...
# 524  524         회기
# 525  525         회룡
# 526  526  회현(남대문시장)
# 527  527      효창공원앞
# 528  528  흑석(중앙대입구)
#
# [529 rows x 2 columns]

# %%
station_code['환승역 수'] = station_code.역.map(s)
station_code
# Out:
#      역코드          역  환승역 수
# 0      0   4.19민주묘지      1
# 1      1         가능      1
# 2      2       가락시장      2
# 3      3    가산디지털단지      2
# 4      4         가양      1
# ..   ...        ...    ...
# 524  524         회기      1
# 525  525         회룡      1
# 526  526  회현(남대문시장)      1
# 527  527      효창공원앞      2
# 528  528  흑석(중앙대입구)      1
#
# [529 rows x 3 columns]

# %%
wc=station_code.set_index("역").to_dict()["환승역 수"]

# %%
img=Image.open("./Det.png")
imgArray=np.array(img)

# %% [markdown]
# #### 환승역 개수로 만든 워드 클라우드

# %%
wordcloud = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250, mask=imgArray)
gen =wordcloud.generate_from_frequencies(wc)
plt.figure(figsize=(20,8))
plt.imshow(gen)

# %% [markdown]
# ### 결과
#  - 연결되는 노선이 많은 환승역일수록 글자가 크게 나온다는 것을 볼 수 있다

# %% [markdown]
# #### 총 승객으로 만든 워드 클라우드

# %%
wc2=df9.set_index("역").to_dict()["총 승객"]

# %%
img2=Image.open("./img6.png")
imgArray2=np.array(img2)

# %%
wordcloud = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250, background_color="white", mask=imgArray2)
gen =wordcloud.generate_from_frequencies(wc2)
plt.figure(figsize=(20,8))
plt.imshow(gen)

# %% [markdown]
# ### 결과
#  - 총 승객이 많은 역일수록 글자가 크게 나온다는 것을 알 수 있다
