# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
print(pd.__version__)
print(sns.__version__)
print(np.__version__)
# Out:
# 1.4.4
# 0.12.0
# 1.23.2

# %%
df=pd.read_csv("DataV2/Total.csv",  index_col=0)
df
# Out:
#       18세 미만  18~24세  25~29세  30~34세  35~39세  40~44세  45~49세  50~54세  55~59세  \
# 2004       1      50     113     181     256     358     410     348     303
# 2005       1      31      91     148     230     307     378     336     273
# 2006       0      33      86     114     179     299     419     342     276
# 2007       1      30      68     113     203     276     347     331     290
# 2008       4      29      70     118     190     300     342     343     293
# 2009       2      31      73      97     148     250     298     303     253
# 2010       2      34      40      90     122     243     318     321     264
# 2011       3      30      50      86     121     183     269     346     277
# 2012       2      24      46     103     123     209     265     274     301
# 2013       2      29      48      74     105     196     241     347     312
# 2014       2      35      39      66     100     159     244     283     325
# 2015       1      35      43      53     103     176     238     271     275
# 2016       1      21      29      40      93     165     233     263     314
# 2017       0      15      45      48      96     166     229     290     329
# 2018       2      31      42      57      92     164     234     325     362
# 2019       0      19      46      56     100     140     228     267     337
# 2020       0      14      41      63      80     132     206     295     315
# 2021       0      20      31      45      95     129     203     312     302
#
#       60~64세  ...  5인 미만  5~9인  10~19인  20~29인  30~49인  50~99인  100~299인  \
# 2004     281  ...    449   263     330     147     213     229       410
# 2005     206  ...    422   254     247     143     189     210       364
# 2006     225  ...    418   249     255     151     178     215       329
# 2007     207  ...    463   221     207     172     187     203       310
# 2008     187  ...    539   191     229     120     142     253       299
# 2009     177  ...    510   176     194     115     130     174       275
# 2010     225  ...    406   198     227     112     163     224       274
# 2011     217  ...    455   193     212     115     157     183       227
# 2012     229  ...    422   238     232     106     160     168       261
# 2013     251  ...    446   182     200     129     159     200       262
# 2014     248  ...    422   189     211     104     152     174       239
# 2015     245  ...    421   198     187     103     153     177       239
# 2016     273  ...    412   194     201     120     150     172       216
# 2017     296  ...    416   223     244     115     150     190       245
# 2018     345  ...    479   224     249     150     183     170       295
# 2019     298  ...    494   221     260     120     150     180       240
# 2020     367  ...    500   228     248     146     181     160       260
# 2021     335  ...    567   234     250     156     152     174       210
#
#       300~499인  500~999인  1000인 이상
# 2004       149       166       230
# 2005       125       154       174
# 2006       116       173       154
# 2007       106       133       157
# 2008        96       140       137
# 2009        93       130       119
# 2010        97       101       129
# 2011        90       113       115
# 2012        77        87       113
# 2013       111       112       128
# 2014       131       122       106
# 2015       128       123        81
# 2016       115       114        83
# 2017       106       177        91
# 2018       136       153       103
# 2019       113       158        84
# 2020        93       162        84
# 2021        88       141       108
#
# [18 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 2004 to 2021
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   18세 미만    18 non-null     int64
#  1   18~24세    18 non-null     int64
#  2   25~29세    18 non-null     int64
#  3   30~34세    18 non-null     int64
#  4   35~39세    18 non-null     int64
#  5   40~44세    18 non-null     int64
#  6   45~49세    18 non-null     int64
#  7   50~54세    18 non-null     int64
#  8   55~59세    18 non-null     int64
#  9   60~64세    18 non-null     int64
#  10  65~69세    18 non-null     int64
#  11  70~74세    18 non-null     int64
#  12  75~79세    18 non-null     int64
#  13  80세 이상    18 non-null     int64
#  14  분류불능      18 non-null     int64
#  15  남         18 non-null     int64
#  16  여         18 non-null     int64
#  17  5인 미만     18 non-null     int64
#  18  5~9인      18 non-null     int64
#  19  10~19인    18 non-null     int64
#  20  20~29인    18 non-null     int64
#  21  30~49인    18 non-null     int64
#  22  50~99인    18 non-null     int64
#  23  100~299인  18 non-null     int64
#  24  300~499인  18 non-null     int64
#  25  500~999인  18 non-null     int64
#  26  1000인 이상  18 non-null     int64
# dtypes: int64(27)
# memory usage: 3.9 KB

# %%
df.describe()
# Out:
#           18세 미만     18~24세      25~29세      30~34세      35~39세      40~44세  \
# count  18.000000  18.000000   18.000000   18.000000   18.000000   18.000000
# mean    1.333333  28.388889   55.611111   86.222222  135.333333  214.000000
# std     1.137593   8.582738   22.893973   38.329156   53.170093   69.619132
# min     0.000000  14.000000   29.000000   40.000000   80.000000  129.000000
# 25%     0.250000  21.750000   41.250000   56.250000   97.000000  164.250000
# 50%     1.000000  30.000000   46.000000   80.000000  113.000000  189.500000
# 75%     2.000000  32.500000   69.500000  110.500000  171.250000  269.500000
# max     4.000000  50.000000  113.000000  181.000000  256.000000  358.000000
#
#            45~49세      50~54세      55~59세      60~64세  ...       5인 미만  \
# count   18.000000   18.000000   18.000000   18.000000  ...   18.000000
# mean   283.444444  310.944444  300.055556  256.222222  ...  457.833333
# std     69.313628   30.631534   28.045073   54.796474  ...   47.493962
# min    203.000000  263.000000  253.000000  177.000000  ...  406.000000
# 25%    233.250000  284.750000  276.250000  219.000000  ...  421.250000
# 50%    254.500000  316.500000  301.500000  246.500000  ...  447.500000
# 75%    336.000000  340.500000  314.750000  292.250000  ...  490.250000
# max    419.000000  348.000000  362.000000  367.000000  ...  567.000000
#
#              5~9인      10~19인      20~29인      30~49인      50~99인    100~299인  \
# count   18.000000   18.000000   18.000000   18.000000   18.000000   18.000000
# mean   215.333333  232.388889  129.111111  163.833333  192.000000  275.277778
# std     26.144395   33.524598   20.667932   20.477391   25.508937   52.344791
# min    176.000000  187.000000  103.000000  130.000000  160.000000  210.000000
# 25%    193.250000  208.000000  115.000000  150.500000  174.000000  239.250000
# 50%    221.000000  230.500000  120.000000  158.000000  181.500000  261.500000
# 75%    232.500000  248.750000  146.750000  180.250000  208.250000  298.000000
# max    263.000000  330.000000  172.000000  213.000000  253.000000  410.000000
#
#          300~499인    500~999인    1000인 이상
# count   18.000000   18.000000   18.000000
# mean   109.444444  136.611111  122.000000
# std     19.097959   25.875582   38.294524
# min     77.000000   87.000000   81.000000
# 25%     93.750000  116.000000   94.000000
# 50%    108.500000  136.500000  114.000000
# 75%    122.750000  157.000000  135.000000
# max    149.000000  177.000000  230.000000
#
# [8 rows x 27 columns]

# %%
df[["18세 미만", "남", "여"]].groupby(["18세 미만"]).mean()
# Out:
#                   남           여
# 18세 미만
# 0       1983.200000   88.200000
# 1       2018.000000  104.800000
# 2       1860.333333   78.333333
# 3       1788.000000   72.000000
# 4       2048.000000   98.000000

# %%
df[["남", "여"]].groupby(["남"]).mean()
# Out:
#           여
# 남
# 1699   78.0
# 1746   64.0
# 1775   75.0
# 1788   72.0
# 1796   68.0
# 1841   75.0
# 1852   77.0
# 1868   63.0
# 1883   74.0
# 1948   72.0
# 1984   96.0
# 1986   76.0
# 2030  112.0
# 2048   98.0
# 2051  108.0
# 2115  123.0
# 2145  137.0
# 2449  137.0

# %%
df["남"].mean()
# Out:
# 1944.6666666666667

# %%
df.mean()
# Out:
# 18세 미만         1.333333
# 18~24세        28.388889
# 25~29세        55.611111
# 30~34세        86.222222
# 35~39세       135.333333
# 40~44세       214.000000
# 45~49세       283.444444
# 50~54세       310.944444
# 55~59세       300.055556
# 60~64세       256.222222
# 65~69세       186.444444
# 70~74세       101.333333
# 75~79세        49.222222
# 80세 이상        19.722222
# 분류불능           5.555556
# 남           1944.666667
# 여             89.166667
# 5인 미만        457.833333
# 5~9인         215.333333
# 10~19인       232.388889
# 20~29인       129.111111
# 30~49인       163.833333
# 50~99인       192.000000
# 100~299인     275.277778
# 300~499인     109.444444
# 500~999인     136.611111
# 1000인 이상     122.000000
# dtype: float64

# %%
g=sns.FacetGrid(df, row="남")
# Out:
# C:\Users\KB\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\KB\miniconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\KB\miniconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
g=sns.FacetGrid(train_df, col="Survived")
