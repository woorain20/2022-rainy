# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
print(pd.__version__)
print(sns.__version__)
print(np.__version__)
# Out:
# 1.4.4
# 0.12.0
# 1.23.2

# %%
df=pd.read_csv("MetroData/22년 1월.csv")
df2=pd.read_csv("MetroData/22년 2월.csv")
df3=pd.read_csv("MetroData/22년 3월.csv")
df4=pd.read_csv("MetroData/22년 4월.csv")
df5=pd.read_csv("MetroData/22년 5월.csv")
df6=pd.read_csv("MetroData/22년 6월.csv")
df7=pd.read_csv("MetroData/22년 7월.csv")
df8=pd.read_csv("MetroData/22년 8월.csv")

# %%
df.head()
# Out:
#         사용일  노선명   역명  승차승객  하차승객
# 0  20220101  3호선   수서  7370  7076
# 1  20220101  3호선  학여울   461   473
# 2  20220101  3호선   대청  3224  2903
# 3  20220101  3호선   일원  3321  2803
# 4  20220101  경원선   창동     1     0

# %%
df[["노선명", "승차승객"]].groupby(["노선명"]).mean()
# Out:
#                   승차승객
# 노선명
# 1호선       17825.509677
# 2호선       21758.838710
# 3호선       12192.941402
# 4호선       14649.332506
# 5호선        9049.910138
# 6호선        6885.377035
# 7호선       10542.973534
# 8호선        8370.405018
# 9호선        8837.771613
# 9호선2~3단계   5857.620347
# 경강선        2241.850440
# 경부선        8940.897436
# 경원선        5337.835359
# 경의선        3277.733662
# 경인선       11086.738710
# 경춘선        1579.791171
# 공항철도 1호선   5742.041475
# 과천선       10038.866935
# 분당선        8588.641050
# 수인선        2552.783154
# 안산선        7244.637717
# 우이신설선      2778.674938
# 일산선        8337.732087
# 장항선        1426.617512
# 중앙선        3412.118280

# %%
df[["노선명", "하차승객"]].groupby(["노선명"]).mean()
# Out:
#                   하차승객
# 노선명
# 1호선       17371.116129
# 2호선       21894.394194
# 3호선       12190.842459
# 4호선       14787.870968
# 5호선        9005.865207
# 6호선        6778.464439
# 7호선       10402.676681
# 8호선        8484.657706
# 9호선        8975.792258
# 9호선2~3단계   5804.717122
# 경강선        2173.826979
# 경부선        8909.472291
# 경원선        5225.664088
# 경의선        3226.749692
# 경인선       10917.141935
# 경춘선        1511.648557
# 공항철도 1호선   5262.488479
# 과천선        9921.298387
# 분당선        8834.743205
# 수인선        2528.908602
# 안산선        7220.344913
# 우이신설선      2690.111663
# 일산선        8091.133956
# 장항선        1382.857143
# 중앙선        3333.423963

# %% [markdown]
# ### 폰트 깨짐 해결 필요

# %%
# 한글 폰트 사용을 위해서 세팅
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import font_manager, rc

font_path = "C:\Windows\Fonts/HYDNKB.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
plt.rc('font', family='KBIZ한마음고딕 R')
print(plt.rcParams['font.family'])
# Out:
# ['KBIZ한마음고딕 R']

# %%
fig=plt.subplots(1, figsize=(18,7))
sns.histplot(x=df["노선명"], y=df["승차승객"], bins=100)
plt.show()

# %%
fig=plt.subplots(1, figsize=(18,7))
sns.histplot(x=df["승차승객"], bins=100)
plt.show()

# %%
fig=plt.subplots(1, figsize=(18,7))
sns.barplot(y=df["승차승객"], x=df["노선명"])
plt.show()

# %%
fig=plt.subplots(1, figsize=(18,10))
sns.barplot(x=df["승차승객"], y=df["노선명"])
plt.show()

# %%
fig=plt.subplots(1, figsize=(18,10))
sns.barplot(x=df["하차승객"], y=df["노선명"])
plt.show()

# %%
fig=plt.subplots(1, figsize=(10,100))
sns.barplot(x=df["승차승객"], y=df["역명"])
plt.show()

# %%
fig=plt.subplots(1, figsize=(10,100))
sns.barplot(x=df["하차승객"], y=df["역명"])
plt.show()

# %%
df9=pd.read_csv("../MetroData/2022.csv")

# %%
df9.mean()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_5208\2323031499.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df9.mean()
# 승차승객      9826.457275
# 하차승객      9791.574585
# 총 승객     19618.031860
# 승차-하차       34.882691
# 월            4.541161
# 일           15.706442
# dtype: float64
